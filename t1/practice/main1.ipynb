# %%
(451 - 32) * 5 / 9
# Out:
# 232.77777777777777

# %%
4 % 2 == 0
# Out:
# True

# %%
9349//1000 == 9349%10
# Out:
# True

# %%
(-7)//3, (-7)%3, 7//3 == 7%3
# Out:
# (-3, 2, False, 2)

# %%
2**100000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
5/3, 2/3+1, 5/3==2/3+1
# Out:
# (1.6666666666666667, 1.6666666666666665, False)

# %%
0.1+0.2, 0.3, 0.1+0.2==0.3
# Out:
# (0.30000000000000004, 0.3, False)

# %%
import math
math.isclose(0.1+0.2, 0.3)
# Out:
# True

# %%
10_000_000_000 + 1/10_000_000
# Out:
# 10000000000.0

# %%
2.0==2, 2.0 is 2
# Out:
# <>:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# /var/folders/pl/x96m0d8j04zcy122vhwlncqc0000gn/T/ipykernel_38474/2068066105.py:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
#   2.0==2, 2.0 is 2
# (True, False)

# %%
10**10 is 10**10
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /var/folders/pl/x96m0d8j04zcy122vhwlncqc0000gn/T/ipykernel_38474/876431402.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   10**10 is 10**10
# True

# %%
10**100 is 10**100, 10*100 == 10*100
# Out:
# (False, True)

# %%
math.sqrt(5) == 5**(1/2) == pow(5, 0.5)
# Out:
# True

# %%
3.14 // 1
# Out:
# 3.0

# %%
round(3.141592, 2)
# Out:
# 3.14

# %%
# округлення до найближчого парного (для 0.5),
# щоб скомпенсувати похибку (банківське округлення)
round(2.5), round(1.5)
# Out:
# (2, 2)

# %%
max(3, -1, 20), min(3, -1, 20)
# Out:
# (20, -1)

# %%
4 <= 5 <= 9
# Out:
# True

# %%
1 < 4 == 4 <= 4
# Out:
# True

# %%
6 + 20 > 31 and 20 + 31 > 6 and 6 + 31 > 20
# Out:
# False

# %%
False + False, True + True, True + False
# Out:
# (0, 2, 1)

# %%
True + 1, True + 1.0, True + 0j
# Out:
# (2, 2.0, (1+0j))

# %%
True and True or False, False and True or False, True or False and True
# Out:
# (True, False, True)

# %%
# 2 == not 3 - syntax error
# not 2 == not 3 - syntax error
not 2 == 3
# Out:
# True

# %%
0 or 5 and 1, 5 and 1 or 0
# Out:
# (1, 1)

# %%
# 0 or 5 and 1/0 - error, 0 diviaion
1 or 5 and 1/0
# Out:
# 1

# %%
# math.cbrt() - для дійсних чисел
(-1)**(1/3), pow(-1, 1/3), math.cbrt(-1)
# Out:
# ((0.5000000000000001+0.8660254037844386j),
#  (0.5000000000000001+0.8660254037844386j),
#  -1.0)
