# %%
a = 'ab'
a, b = a
a, b
# Out:
# ('a', 'b')

# %%
num = input()
n_1, n_2, *other_n = num
print(n_1, n_2, other_n)
# Out:
# 1 2 ['3', '4', '5']

# %%
num = input()
*other_n, n_1, n_2 = num
print(other_n, n_1, n_2)
# Out:
# ['1', '2', '3'] 4 5
