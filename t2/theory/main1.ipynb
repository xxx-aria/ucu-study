# %% [markdown]
# ### is operator

# %%
x = 'a'
y = x
z = 'a'
x is y, x is z
# Out:
# (True, True)

# %%
x = [1]
y = x
z = [1]
x is y, x is z
# Out:
# (True, False)

# %%
10**10 is 10**10, 10**100 is 10**100
# Out:
# (True, False)

# %%
x = 10**10
y = 10**10
x is y
# Out:
# False

# %%
x = 'a' + 'b'
y = 'ab'
x is y
# Out:
# True

# %%
x = 'a'.upper()
y = 'A'
x is y
# Out:
# False

# %%
nums = [1, [2, 3]]
x = nums[0]
print(x is nums[0])
x += 1
y = nums[1]
y += [4]
print(nums)
# Out:
# True
# [1, [2, 3, 4]]

# %%
nums = [1, [2, 3]]
for x in nums:
    x *= 2
nums
# Out:
# [1, [2, 3, 2, 3]]

# %%
def change(x): # x = num, x / num_list
    x *= 2
num = 1
change(num)
num_list = [1]
change(num_list)
num, num_list
# Out:
# (1, [1, 1])

# %%
def foo(nums=[1, 2, 3]):
    nums += [1]
    print(nums)
foo()
foo()
foo()
# Out:
# [1, 2, 3, 1]
# [1, 2, 3, 1, 1]
# [1, 2, 3, 1, 1, 1]
